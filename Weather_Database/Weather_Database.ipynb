# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 742

# %%
#Import dependencies
import requests
from config import weather_api_key


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=350393fc9343bf41f1f18f4534f41836

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | hobyo
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | naqadeh
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | fortuna
# Processing Record 9 of Set 1 | zyryanka
# Processing Record 10 of Set 1 | kimbe
# Processing Record 11 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | launceston
# Processing Record 18 of Set 1 | japura
# Processing Record 19 of Set 1 | pisco
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | mitsamiouli
# Processing Record 22 of Set 1 | severo-yeniseyskiy
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | hamilton
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | chokurdakh
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | saint-georges
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | tazovskiy
# Processing Record 35 of Set 1 | port shepstone
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | roald
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | zhangjiakou
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | hofn
# Processing Record 43 of Set 1 | half moon bay
# Processing Record 44 of Set 1 | konya
# Processing Record 45 of Set 1 | omboue
# Processing Record 46 of Set 1 | ancud
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | egvekinot
# Processing Record 49 of Set 1 | tarko-sale
# Processing Record 50 of Set 1 | faya
# Processing Record 1 of Set 2 | casino
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | naudero
# Processing Record 6 of Set 2 | guerrero negro
# Processing Record 7 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | hasaki
# Processing Record 10 of Set 2 | chicama
# Processing Record 11 of Set 2 | homestead
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | general pico
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | lamovita
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | druzhba
# Processing Record 24 of Set 2 | lensk
# Processing Record 25 of Set 2 | kayerkan
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | orzhytsya
# Processing Record 30 of Set 2 | nishihara
# Processing Record 31 of Set 2 | teguise
# Processing Record 32 of Set 2 | chernyshevskiy
# Processing Record 33 of Set 2 | sao joao da barra
# Processing Record 34 of Set 2 | andenes
# Processing Record 35 of Set 2 | nueva helvecia
# Processing Record 36 of Set 2 | bonthe
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | saint-pierre
# Processing Record 39 of Set 2 | beidao
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | cervo
# Processing Record 42 of Set 2 | lincoln
# Processing Record 43 of Set 2 | padang
# Processing Record 44 of Set 2 | kavieng
# Processing Record 45 of Set 2 | gedo
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | kruisfontein
# Processing Record 48 of Set 2 | carutapera
# Processing Record 49 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | manali
# Processing Record 2 of Set 3 | broome
# Processing Record 3 of Set 3 | lokosovo
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | bud
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | micheweni
# Processing Record 11 of Set 3 | itoman
# Processing Record 12 of Set 3 | tabas
# Processing Record 13 of Set 3 | chifeng
# Processing Record 14 of Set 3 | pemangkat
# Processing Record 15 of Set 3 | tiksi
# Processing Record 16 of Set 3 | luanda
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | kouango
# Processing Record 19 of Set 3 | maragogi
# Processing Record 20 of Set 3 | deputatskiy
# Processing Record 21 of Set 3 | alyangula
# Processing Record 22 of Set 3 | bilma
# Processing Record 23 of Set 3 | mount gambier
# Processing Record 24 of Set 3 | fenoarivo
# Processing Record 25 of Set 3 | mahanoro
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | bosaso
# Processing Record 28 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 3 | mocuba
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 3 | kyrylivka
# Processing Record 34 of Set 3 | walvis bay
# Processing Record 35 of Set 3 | bathsheba
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | havre-saint-pierre
# Processing Record 38 of Set 3 | port arthur
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | eyemouth
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 3 | muros
# Processing Record 44 of Set 3 | sorland
# Processing Record 45 of Set 3 | khrebtovaya
# Processing Record 46 of Set 3 | la ronge
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | teplodar
# Processing Record 49 of Set 3 | vila franca do campo
# Processing Record 50 of Set 3 | okhotsk
# Processing Record 1 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | bageshwar
# Processing Record 4 of Set 4 | leningradskiy
# Processing Record 5 of Set 4 | dno
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | lompoc
# Processing Record 10 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 4 | diego de almagro
# Processing Record 12 of Set 4 | loukhi
# Processing Record 13 of Set 4 | san carlos del zulia
# Processing Record 14 of Set 4 | shingu
# Processing Record 15 of Set 4 | prado
# Processing Record 16 of Set 4 | voyvozh
# Processing Record 17 of Set 4 | derzhavinsk
# Processing Record 18 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 4 | inhambane
# Processing Record 20 of Set 4 | wamba
# Processing Record 21 of Set 4 | makakilo city
# Processing Record 22 of Set 4 | turukhansk
# Processing Record 23 of Set 4 | severodvinsk
# Processing Record 24 of Set 4 | katsuura
# Processing Record 25 of Set 4 | aneho
# Processing Record 26 of Set 4 | kungurtug
# Processing Record 27 of Set 4 | cap malheureux
# Processing Record 28 of Set 4 | beloha
# Processing Record 29 of Set 4 | husavik
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | northampton
# Processing Record 32 of Set 4 | dukat
# Processing Record 33 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 4 | ndele
# Processing Record 35 of Set 4 | hachinohe
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | trelew
# Processing Record 38 of Set 4 | shimoda
# Processing Record 39 of Set 4 | lakes entrance
# Processing Record 40 of Set 4 | la palma
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | east london
# Processing Record 43 of Set 4 | clyde river
# Processing Record 44 of Set 4 | sept-iles
# Processing Record 45 of Set 4 | solnechnyy
# Processing Record 46 of Set 4 | elk city
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | schwandorf
# Processing Record 49 of Set 4 | langarud
# Processing Record 50 of Set 4 | kantyshevo
# Processing Record 1 of Set 5 | nicoya
# Processing Record 2 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 3 of Set 5 | pangnirtung
# Processing Record 4 of Set 5 | narsaq
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | katobu
# Processing Record 7 of Set 5 | port hedland
# Processing Record 8 of Set 5 | nikolskoye
# Processing Record 9 of Set 5 | moron
# Processing Record 10 of Set 5 | casas grandes
# Processing Record 11 of Set 5 | yar-sale
# Processing Record 12 of Set 5 | prata
# Processing Record 13 of Set 5 | puerto del rosario
# Processing Record 14 of Set 5 | vilyuysk
# Processing Record 15 of Set 5 | pulsano
# Processing Record 16 of Set 5 | port lincoln
# Processing Record 17 of Set 5 | dumas
# Processing Record 18 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 5 | puerto baquerizo moreno
# Processing Record 20 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 5 | namibe
# Processing Record 22 of Set 5 | washougal
# Processing Record 23 of Set 5 | vanderhoof
# Processing Record 24 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 5 | simao
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | vao
# Processing Record 28 of Set 5 | livramento
# Processing Record 29 of Set 5 | garden city
# Processing Record 30 of Set 5 | fort saint james
# Processing Record 31 of Set 5 | sola
# Processing Record 32 of Set 5 | dicabisagan
# Processing Record 33 of Set 5 | srisailam
# Processing Record 34 of Set 5 | thinadhoo
# Processing Record 35 of Set 5 | pundaguitan
# Processing Record 36 of Set 5 | port elizabeth
# Processing Record 37 of Set 5 | mago
# Processing Record 38 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 5 | burica
# City not found. Skipping...
# Processing Record 40 of Set 5 | luderitz
# Processing Record 41 of Set 5 | camabatela
# Processing Record 42 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 5 | surt
# Processing Record 44 of Set 5 | iqaluit
# Processing Record 45 of Set 5 | kitimat
# Processing Record 46 of Set 5 | vinh
# Processing Record 47 of Set 5 | numi
# City not found. Skipping...
# Processing Record 48 of Set 5 | sur
# Processing Record 49 of Set 5 | muisne
# Processing Record 50 of Set 5 | ennis
# Processing Record 1 of Set 6 | sao gabriel da cachoeira
# Processing Record 2 of Set 6 | gurmatkal
# Processing Record 3 of Set 6 | taybad
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | pasni
# Processing Record 6 of Set 6 | concordia
# Processing Record 7 of Set 6 | roma
# Processing Record 8 of Set 6 | wuhan
# Processing Record 9 of Set 6 | aitape
# Processing Record 10 of Set 6 | viedma
# Processing Record 11 of Set 6 | lorengau
# Processing Record 12 of Set 6 | pouebo
# Processing Record 13 of Set 6 | comodoro rivadavia
# Processing Record 14 of Set 6 | san juan bautista
# Processing Record 15 of Set 6 | lucapa
# Processing Record 16 of Set 6 | kalmunai
# Processing Record 17 of Set 6 | skibbereen
# Processing Record 18 of Set 6 | pudozh
# Processing Record 19 of Set 6 | jacmel
# Processing Record 20 of Set 6 | karabulak
# Processing Record 21 of Set 6 | chuy
# Processing Record 22 of Set 6 | durazno
# Processing Record 23 of Set 6 | yulara
# Processing Record 24 of Set 6 | puntarenas
# Processing Record 25 of Set 6 | georgetown
# Processing Record 26 of Set 6 | rawson
# Processing Record 27 of Set 6 | pafos
# Processing Record 28 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 6 | esperanza
# Processing Record 30 of Set 6 | saint anthony
# Processing Record 31 of Set 6 | san patricio
# Processing Record 32 of Set 6 | santa rosa
# Processing Record 33 of Set 6 | riyadh
# Processing Record 34 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 6 | coquimbo
# Processing Record 36 of Set 6 | saint-philippe
# Processing Record 37 of Set 6 | castro
# Processing Record 38 of Set 6 | betioky
# Processing Record 39 of Set 6 | rundu
# Processing Record 40 of Set 6 | teacapan
# Processing Record 41 of Set 6 | ixtapa
# Processing Record 42 of Set 6 | sidi bu zayd
# City not found. Skipping...
# Processing Record 43 of Set 6 | gamba
# Processing Record 44 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 6 | homer
# Processing Record 46 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 6 | kisangani
# Processing Record 48 of Set 6 | rach gia
# Processing Record 49 of Set 6 | ravar
# Processing Record 50 of Set 6 | geraldton
# Processing Record 1 of Set 7 | severo-kurilsk
# Processing Record 2 of Set 7 | tura
# Processing Record 3 of Set 7 | waipawa
# Processing Record 4 of Set 7 | male
# Processing Record 5 of Set 7 | koungou
# Processing Record 6 of Set 7 | orgun
# City not found. Skipping...
# Processing Record 7 of Set 7 | mweka
# Processing Record 8 of Set 7 | mahibadhoo
# Processing Record 9 of Set 7 | port macquarie
# Processing Record 10 of Set 7 | pokaran
# Processing Record 11 of Set 7 | craig
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | erzin
# Processing Record 14 of Set 7 | mecca
# Processing Record 15 of Set 7 | yerbogachen
# Processing Record 16 of Set 7 | ciudad bolivar
# Processing Record 17 of Set 7 | aryanah
# Processing Record 18 of Set 7 | acapulco
# Processing Record 19 of Set 7 | kostomuksha
# Processing Record 20 of Set 7 | praia da vitoria
# Processing Record 21 of Set 7 | ust-maya
# Processing Record 22 of Set 7 | gat
# Processing Record 23 of Set 7 | adrar
# Processing Record 24 of Set 7 | qaqortoq
# Processing Record 25 of Set 7 | ambon
# Processing Record 26 of Set 7 | sao jose da coroa grande
# Processing Record 27 of Set 7 | bara
# Processing Record 28 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 29 of Set 7 | dondo
# Processing Record 30 of Set 7 | dunedin
# Processing Record 31 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 7 | belaya gora
# Processing Record 33 of Set 7 | opuwo
# Processing Record 34 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 35 of Set 7 | grand gaube
# Processing Record 36 of Set 7 | aklavik
# Processing Record 37 of Set 7 | pryazha
# Processing Record 38 of Set 7 | kahului
# Processing Record 39 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 7 | ust-kuyga
# Processing Record 41 of Set 7 | kedougou
# Processing Record 42 of Set 7 | srednekolymsk
# Processing Record 43 of Set 7 | neiafu
# Processing Record 44 of Set 7 | tahoua
# Processing Record 45 of Set 7 | umarkot
# Processing Record 46 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 7 | cidreira
# Processing Record 48 of Set 7 | abu dhabi
# Processing Record 49 of Set 7 | prestea
# Processing Record 50 of Set 7 | flinders
# Processing Record 1 of Set 8 | pahrump
# Processing Record 2 of Set 8 | stornoway
# Processing Record 3 of Set 8 | bismarck
# Processing Record 4 of Set 8 | poum
# Processing Record 5 of Set 8 | yakeshi
# Processing Record 6 of Set 8 | pilar
# Processing Record 7 of Set 8 | wukari
# Processing Record 8 of Set 8 | fare
# Processing Record 9 of Set 8 | mahon
# Processing Record 10 of Set 8 | ostrovnoy
# Processing Record 11 of Set 8 | vostok
# Processing Record 12 of Set 8 | ukiah
# Processing Record 13 of Set 8 | springfield
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 8 | saint-joseph
# Processing Record 17 of Set 8 | karratha
# Processing Record 18 of Set 8 | san quintin
# Processing Record 19 of Set 8 | uusikaupunki
# Processing Record 20 of Set 8 | dinar
# Processing Record 21 of Set 8 | malanje
# Processing Record 22 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 8 | seymchan
# Processing Record 24 of Set 8 | toulepleu
# City not found. Skipping...
# Processing Record 25 of Set 8 | eslov
# Processing Record 26 of Set 8 | sidi ali
# Processing Record 27 of Set 8 | bandarbeyla
# Processing Record 28 of Set 8 | bintulu
# Processing Record 29 of Set 8 | nioro
# Processing Record 30 of Set 8 | waingapu
# Processing Record 31 of Set 8 | petropavlovka
# Processing Record 32 of Set 8 | tayu
# Processing Record 33 of Set 8 | constitucion
# Processing Record 34 of Set 8 | ritchie
# Processing Record 35 of Set 8 | boralday
# Processing Record 36 of Set 8 | gorbanesti
# Processing Record 37 of Set 8 | fairmont
# Processing Record 38 of Set 8 | darnah
# Processing Record 39 of Set 8 | lewistown
# Processing Record 40 of Set 8 | sinegorye
# Processing Record 41 of Set 8 | portree
# Processing Record 42 of Set 8 | wanning
# Processing Record 43 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 44 of Set 8 | san ignacio
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | genhe
# Processing Record 47 of Set 8 | labuhan
# Processing Record 48 of Set 8 | oussouye
# Processing Record 49 of Set 8 | yarmouth
# Processing Record 50 of Set 8 | spencer
# Processing Record 1 of Set 9 | conde
# Processing Record 2 of Set 9 | santa catalina
# Processing Record 3 of Set 9 | antigonish
# Processing Record 4 of Set 9 | polonnaruwa
# Processing Record 5 of Set 9 | port blair
# Processing Record 6 of Set 9 | casale monferrato
# Processing Record 7 of Set 9 | batticaloa
# Processing Record 8 of Set 9 | monte cristi
# City not found. Skipping...
# Processing Record 9 of Set 9 | yaring
# Processing Record 10 of Set 9 | tateyama
# Processing Record 11 of Set 9 | almenara
# Processing Record 12 of Set 9 | butembo
# Processing Record 13 of Set 9 | ligayan
# Processing Record 14 of Set 9 | mount isa
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | atlantic beach
# Processing Record 17 of Set 9 | alofi
# Processing Record 18 of Set 9 | raudeberg
# Processing Record 19 of Set 9 | henties bay
# Processing Record 20 of Set 9 | tilichiki
# Processing Record 21 of Set 9 | meulaboh
# Processing Record 22 of Set 9 | malatya
# Processing Record 23 of Set 9 | berlevag
# Processing Record 24 of Set 9 | catazaja
# Processing Record 25 of Set 9 | pontianak
# Processing Record 26 of Set 9 | arkadak
# Processing Record 27 of Set 9 | santa fe
# Processing Record 28 of Set 9 | port-gentil
# Processing Record 29 of Set 9 | daru
# Processing Record 30 of Set 9 | sobolevo
# Processing Record 31 of Set 9 | sakaiminato
# Processing Record 32 of Set 9 | tabou
# Processing Record 33 of Set 9 | bodden town
# Processing Record 34 of Set 9 | menongue
# Processing Record 35 of Set 9 | tyrma
# Processing Record 36 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 9 | gumushane
# City not found. Skipping...
# Processing Record 38 of Set 9 | shenzhen
# Processing Record 39 of Set 9 | buraydah
# Processing Record 40 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 9 | mackay
# Processing Record 42 of Set 9 | saint austell
# Processing Record 43 of Set 9 | nanortalik
# Processing Record 44 of Set 9 | ust-nera
# Processing Record 45 of Set 9 | tynda
# Processing Record 46 of Set 9 | banjar
# Processing Record 47 of Set 9 | ambilobe
# Processing Record 48 of Set 9 | karatuzskoye
# Processing Record 49 of Set 9 | aranos
# Processing Record 50 of Set 9 | idanre
# Processing Record 1 of Set 10 | phan thiet
# Processing Record 2 of Set 10 | warrington
# Processing Record 3 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 10 | saint-francois
# Processing Record 5 of Set 10 | caranavi
# Processing Record 6 of Set 10 | verkhoyansk
# Processing Record 7 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 10 | port hardy
# Processing Record 9 of Set 10 | raha
# Processing Record 10 of Set 10 | rio grande
# Processing Record 11 of Set 10 | bijie
# Processing Record 12 of Set 10 | tual
# Processing Record 13 of Set 10 | cantagallo
# Processing Record 14 of Set 10 | macusani
# Processing Record 15 of Set 10 | fort myers beach
# Processing Record 16 of Set 10 | jibuti
# Processing Record 17 of Set 10 | kidal
# Processing Record 18 of Set 10 | tombouctou
# Processing Record 19 of Set 10 | capao bonito
# Processing Record 20 of Set 10 | fuerte olimpo
# Processing Record 21 of Set 10 | labytnangi
# Processing Record 22 of Set 10 | bandar-e lengeh
# Processing Record 23 of Set 10 | bereda
# Processing Record 24 of Set 10 | koslan
# Processing Record 25 of Set 10 | bahia blanca
# Processing Record 26 of Set 10 | nome
# Processing Record 27 of Set 10 | jumla
# Processing Record 28 of Set 10 | vaitape
# Processing Record 29 of Set 10 | agirish
# Processing Record 30 of Set 10 | garissa
# Processing Record 31 of Set 10 | avera
# Processing Record 32 of Set 10 | powell river
# Processing Record 33 of Set 10 | ostrovskoye
# Processing Record 34 of Set 10 | tacoaleche
# Processing Record 35 of Set 10 | eloy
# Processing Record 36 of Set 10 | high level
# Processing Record 37 of Set 10 | grindavik
# Processing Record 38 of Set 10 | nuuk
# Processing Record 39 of Set 10 | peniche
# Processing Record 40 of Set 10 | shetpe
# Processing Record 41 of Set 10 | vila do maio
# Processing Record 42 of Set 10 | hambantota
# Processing Record 43 of Set 10 | yumen
# Processing Record 44 of Set 10 | vrangel
# Processing Record 45 of Set 10 | maniitsoq
# Processing Record 46 of Set 10 | camopi
# Processing Record 47 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 10 | port-cartier
# Processing Record 49 of Set 10 | hendek
# Processing Record 50 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 11 | trinidad
# Processing Record 3 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 4 of Set 11 | cittanova
# Processing Record 5 of Set 11 | pryozerne
# Processing Record 6 of Set 11 | gallatin
# Processing Record 7 of Set 11 | sigli
# Processing Record 8 of Set 11 | agadez
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 11 | kosino
# Processing Record 12 of Set 11 | christchurch
# Processing Record 13 of Set 11 | babayurt
# Processing Record 14 of Set 11 | eureka
# Processing Record 15 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 11 | klaksvik
# Processing Record 17 of Set 11 | turbat
# Processing Record 18 of Set 11 | lata
# Processing Record 19 of Set 11 | maneadero
# Processing Record 20 of Set 11 | sisimiut
# Processing Record 21 of Set 11 | yatou
# Processing Record 22 of Set 11 | bay roberts
# Processing Record 23 of Set 11 | dakar
# Processing Record 24 of Set 11 | talnakh
# Processing Record 25 of Set 11 | mandalgovi
# Processing Record 26 of Set 11 | grand-lahou
# Processing Record 27 of Set 11 | kisumu
# Processing Record 28 of Set 11 | ryotsu
# Processing Record 29 of Set 11 | peddapuram
# Processing Record 30 of Set 11 | hastings
# Processing Record 31 of Set 11 | ulaangom
# Processing Record 32 of Set 11 | hervey bay
# Processing Record 33 of Set 11 | codrington
# Processing Record 34 of Set 11 | lerwick
# Processing Record 35 of Set 11 | tarakan
# Processing Record 36 of Set 11 | tabon
# Processing Record 37 of Set 11 | kutum
# Processing Record 38 of Set 11 | port hawkesbury
# Processing Record 39 of Set 11 | pochutla
# Processing Record 40 of Set 11 | te anau
# Processing Record 41 of Set 11 | kisesa
# Processing Record 42 of Set 11 | ulladulla
# Processing Record 43 of Set 11 | puerto penasco
# Processing Record 44 of Set 11 | san cristobal
# Processing Record 45 of Set 11 | miandrivazo
# Processing Record 46 of Set 11 | amapa
# Processing Record 47 of Set 11 | mandali
# Processing Record 48 of Set 11 | araouane
# Processing Record 49 of Set 11 | shushtar
# Processing Record 50 of Set 11 | el alto
# Processing Record 1 of Set 12 | abalak
# Processing Record 2 of Set 12 | svetlyy
# Processing Record 3 of Set 12 | baglung
# Processing Record 4 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 5 of Set 12 | samarai
# Processing Record 6 of Set 12 | delmas
# Processing Record 7 of Set 12 | bonavista
# Processing Record 8 of Set 12 | tigil
# Processing Record 9 of Set 12 | chapais
# Processing Record 10 of Set 12 | vardo
# Processing Record 11 of Set 12 | price
# Processing Record 12 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 12 | filadelfia
# Processing Record 14 of Set 12 | la cruz
# Processing Record 15 of Set 12 | athens
# Processing Record 16 of Set 12 | puerto lempira
# Processing Record 17 of Set 12 | kashi
# Processing Record 18 of Set 12 | mantua
# Processing Record 19 of Set 12 | aborlan
# Processing Record 20 of Set 12 | dolores
# Processing Record 21 of Set 12 | kitui
# Processing Record 22 of Set 12 | kununurra
# Processing Record 23 of Set 12 | buala
# Processing Record 24 of Set 12 | teguldet
# Processing Record 25 of Set 12 | bay city
# Processing Record 26 of Set 12 | torbay
# Processing Record 27 of Set 12 | alihe
# Processing Record 28 of Set 12 | west bay
# Processing Record 29 of Set 12 | richards bay
# Processing Record 30 of Set 12 | micoud
# Processing Record 31 of Set 12 | davila
# Processing Record 32 of Set 12 | vanavara
# Processing Record 33 of Set 12 | saint-paul
# Processing Record 34 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 12 | honiara
# Processing Record 36 of Set 12 | zhezkazgan
# Processing Record 37 of Set 12 | haines junction
# Processing Record 38 of Set 12 | akdepe
# Processing Record 39 of Set 12 | shenjiamen
# Processing Record 40 of Set 12 | ahipara
# Processing Record 41 of Set 12 | boksitogorsk
# Processing Record 42 of Set 12 | marzuq
# Processing Record 43 of Set 12 | tromso
# Processing Record 44 of Set 12 | tucuman
# Processing Record 45 of Set 12 | tautira
# Processing Record 46 of Set 12 | anqing
# Processing Record 47 of Set 12 | souillac
# Processing Record 48 of Set 12 | luau
# Processing Record 49 of Set 12 | bambanglipuro
# Processing Record 50 of Set 12 | pascagoula
# Processing Record 1 of Set 13 | ca mau
# Processing Record 2 of Set 13 | garlasco
# Processing Record 3 of Set 13 | golyshmanovo
# Processing Record 4 of Set 13 | mana
# Processing Record 5 of Set 13 | portland
# Processing Record 6 of Set 13 | jambi
# Processing Record 7 of Set 13 | odweyne
# Processing Record 8 of Set 13 | assen
# Processing Record 9 of Set 13 | celestun
# Processing Record 10 of Set 13 | hede
# Processing Record 11 of Set 13 | nouakchott
# Processing Record 12 of Set 13 | gornyak
# Processing Record 13 of Set 13 | taicheng
# Processing Record 14 of Set 13 | ouadda
# Processing Record 15 of Set 13 | iquique
# Processing Record 16 of Set 13 | ahuimanu
# Processing Record 17 of Set 13 | marang
# Processing Record 18 of Set 13 | northam
# Processing Record 19 of Set 13 | salamanca
# Processing Record 20 of Set 13 | natal
# Processing Record 21 of Set 13 | goderich
# Processing Record 22 of Set 13 | puerto carreno
# Processing Record 23 of Set 13 | bayji
# Processing Record 24 of Set 13 | bairiki
# Processing Record 25 of Set 13 | lagoa
# Processing Record 26 of Set 13 | barra do bugres
# Processing Record 27 of Set 13 | xiaoweizhai
# Processing Record 28 of Set 13 | urucara
# Processing Record 29 of Set 13 | finschhafen
# Processing Record 30 of Set 13 | victor harbor
# Processing Record 31 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 13 | merritt
# Processing Record 33 of Set 13 | bosanska kostajnica
# Processing Record 34 of Set 13 | chulman
# Processing Record 35 of Set 13 | alaca
# Processing Record 36 of Set 13 | pringsewu
# Processing Record 37 of Set 13 | krasnoselkup
# Processing Record 38 of Set 13 | xiongyue
# Processing Record 39 of Set 13 | afua
# Processing Record 40 of Set 13 | portadown
# Processing Record 41 of Set 13 | teluknaga
# Processing Record 42 of Set 13 | sechura
# Processing Record 43 of Set 13 | voh
# Processing Record 44 of Set 13 | san isidro
# Processing Record 45 of Set 13 | isoka
# Processing Record 46 of Set 13 | alindao
# Processing Record 47 of Set 13 | sant julia de loria
# Processing Record 48 of Set 13 | bubaque
# Processing Record 49 of Set 13 | balkanabat
# Processing Record 50 of Set 13 | bom jesus
# Processing Record 1 of Set 14 | bilyayivka
# Processing Record 2 of Set 14 | gillette
# Processing Record 3 of Set 14 | escarcega
# Processing Record 4 of Set 14 | cayenne
# Processing Record 5 of Set 14 | bagru
# Processing Record 6 of Set 14 | touros
# Processing Record 7 of Set 14 | baie-saint-paul
# Processing Record 8 of Set 14 | svetlaya
# Processing Record 9 of Set 14 | champerico
# Processing Record 10 of Set 14 | lisakovsk
# Processing Record 11 of Set 14 | ossora
# Processing Record 12 of Set 14 | kathu
# Processing Record 13 of Set 14 | erdaojiang
# Processing Record 14 of Set 14 | pemba
# Processing Record 15 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 14 | plast
# Processing Record 17 of Set 14 | newcastle
# Processing Record 18 of Set 14 | valparaiso
# Processing Record 19 of Set 14 | jiamusi
# Processing Record 20 of Set 14 | kodinsk
# Processing Record 21 of Set 14 | ashland
# Processing Record 22 of Set 14 | verkhnevilyuysk
# Processing Record 23 of Set 14 | benghazi
# Processing Record 24 of Set 14 | bor
# Processing Record 25 of Set 14 | olafsvik
# Processing Record 26 of Set 14 | ilulissat
# Processing Record 27 of Set 14 | prieska
# Processing Record 28 of Set 14 | dongli
# Processing Record 29 of Set 14 | onega
# Processing Record 30 of Set 14 | tarauaca
# Processing Record 31 of Set 14 | chateauroux
# Processing Record 32 of Set 14 | cabinda
# Processing Record 33 of Set 14 | letham
# Processing Record 34 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 14 | udachnyy
# Processing Record 36 of Set 14 | cubara
# Processing Record 37 of Set 14 | aurillac
# Processing Record 38 of Set 14 | imbituba
# Processing Record 39 of Set 14 | gwanda
# Processing Record 40 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 41 of Set 14 | paamiut
# Processing Record 42 of Set 14 | itarema
# Processing Record 43 of Set 14 | halifax
# Processing Record 44 of Set 14 | timra
# Processing Record 45 of Set 14 | kokopo
# Processing Record 46 of Set 14 | anchorage
# Processing Record 47 of Set 14 | mezen
# Processing Record 48 of Set 14 | caravelas
# Processing Record 49 of Set 14 | alekseyevskoye
# Processing Record 50 of Set 14 | tlapacoyan
# Processing Record 1 of Set 15 | ampanihy
# Processing Record 2 of Set 15 | grand-santi
# Processing Record 3 of Set 15 | frederikshavn
# Processing Record 4 of Set 15 | jacareacanga
# Processing Record 5 of Set 15 | cambridge
# Processing Record 6 of Set 15 | sal rei
# Processing Record 7 of Set 15 | quelimane
# Processing Record 8 of Set 15 | winnemucca
# Processing Record 9 of Set 15 | capitao poco
# Processing Record 10 of Set 15 | kjollefjord
# Processing Record 11 of Set 15 | asfi
# Processing Record 12 of Set 15 | sao teotonio
# Processing Record 13 of Set 15 | nantucket
# Processing Record 14 of Set 15 | gurupi
# Processing Record 15 of Set 15 | mackenzie
# Processing Record 16 of Set 15 | calvinia
# Processing Record 17 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 15 | cap-aux-meules
# Processing Record 19 of Set 15 | pathein
# Processing Record 20 of Set 15 | hokitika
# Processing Record 21 of Set 15 | acuitzio
# Processing Record 22 of Set 15 | oistins
# Processing Record 23 of Set 15 | kudahuvadhoo
# Processing Record 24 of Set 15 | burns lake
# Processing Record 25 of Set 15 | impfondo
# Processing Record 26 of Set 15 | fairbanks
# Processing Record 27 of Set 15 | seguin
# Processing Record 28 of Set 15 | westport
# Processing Record 29 of Set 15 | shizunai
# Processing Record 30 of Set 15 | nautla
# Processing Record 31 of Set 15 | jaguarari
# Processing Record 32 of Set 15 | salekhard
# Processing Record 33 of Set 15 | kailua
# Processing Record 34 of Set 15 | onguday
# Processing Record 35 of Set 15 | chaa-khol
# City not found. Skipping...
# Processing Record 36 of Set 15 | mildura
# Processing Record 37 of Set 15 | makasar
# Processing Record 38 of Set 15 | nelson
# Processing Record 39 of Set 15 | sao joao de pirabas
# Processing Record 40 of Set 15 | kharan
# Processing Record 41 of Set 15 | atambua
# Processing Record 42 of Set 15 | abu samrah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint George      US  37.1041 -113.5841     32.79        59           1
# 1         Hobyo      SO   5.3505   48.5268     79.36        84          55
# 2         Kapaa      US  22.0752 -159.3190     71.19        84          75
# 3       Naqadeh      IR  36.9553   45.3880     26.87        77          19
# 4       Mataura      NZ -46.1927  168.8643     60.48        75         100
# 5     Busselton      AU -33.6500  115.3333     64.09        78           0
# 6       Fortuna      US  40.5982 -124.1573     53.94        91          90
# 7      Zyryanka      RU  65.7500  150.8500    -29.06        97          69
# 8         Kimbe      PG  -5.5502  150.1429     76.24        94         100
# 9        Hobart      AU -42.8794  147.3294     57.06        74          90
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1       14.18       broken clouds
# 2        8.05       moderate rain
# 3        4.32          few clouds
# 4        0.60     overcast clouds
# 5       16.06           clear sky
# 6        8.01          light rain
# 7        9.40       broken clouds
# 8        2.13       moderate rain
# 9        1.01     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
